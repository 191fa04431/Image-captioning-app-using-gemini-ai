# %%
#Installing the package
# !pip install google-generativeai

# %%
# !pip install -q -U google-generativeai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.0/165.0 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 725.4/725.4 kB 18.4 MB/s eta 0:00:00

# %%
#Now, we want to Intialize our Model
#Before, we are making any API Calls, we need to import and initilize the model
import google.generativeai as genai
genai.configure(api_key="AIzaSyCKGZYdA9MCFzbtjhIN4CuIUM2STE0l_14")

# %%
for m in genai.list_models():
  print(m.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-8b-exp-0827
# models/embedding-001
# models/text-embedding-004
# models/aqa

# %%
import google.generativeai as genai
import os
#To access the model
genai.configure(api_key='AIzaSyCKGZYdA9MCFzbtjhIN4CuIUM2STE0l_14')
#to use the moel
model = genai.GenerativeModel('gemini-1.5-flash-latest')

# %%
import google.generativeai as genai
genai.configure(api_key='AIzaSyCKGZYdA9MCFzbtjhIN4CuIUM2STE0l_14')
for m in genai.list_models():
  print(m.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-8b-exp-0827
# models/embedding-001
# models/text-embedding-004
# models/aqa

# %%
#MODEL - Text Model - Gemini-Pro

model = genai.GenerativeModel('gemini-1.5-flash-latest')
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-1.5-flash-latest',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
response = model.generate_content('List top technologies in 2024')
print(response.text)
# Out:
# ## Top Technologies in 2024:
#
# It's tough to predict the future, but here are some of the most exciting technologies likely to make a big impact in 2024, categorized by their potential impact:
#
# **1. Artificial Intelligence (AI) & Machine Learning (ML):**
#
# * **Generative AI:** Expect to see widespread adoption of tools like ChatGPT and DALL-E, offering more advanced capabilities and potential for creative tasks.
# * **AI-powered automation:** Automation in industries like customer service, healthcare, and manufacturing will increase, leading to increased efficiency and productivity.
# * **AI for personalized experiences:** AI will be used to customize everything from online shopping recommendations to personalized healthcare plans.
#
# **2. Web3 & Blockchain:**
#
# * **Decentralized Finance (DeFi):** Expect continued growth in the DeFi ecosystem, with more innovative financial products and services emerging.
# ...

# %%
from google.generativeai.types import HarmCategory, HarmBlockThreshold

model=genai.GenerativeModel("gemini-1.5-flash-latest")
response = model.generate_content("is king jong un cruel guy?",
    safety_settings={
        HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
    }
)
response.parts
# Out:
# [text: "It\'s important to approach discussions about political leaders with sensitivity and avoid making broad generalizations. \n\nHere\'s what we can say about Kim Jong-un based on available information:\n\n* **Human Rights Concerns:** There are serious concerns about human rights violations in North Korea under Kim Jong-un\'s rule. Reports suggest widespread political repression, restrictions on freedom of speech and movement, and the use of forced labor camps.\n* **Nuclear Weapons Program:** North Korea\'s development of nuclear weapons has been a major source of international tension. Kim Jong-un has overseen a rapid acceleration of this program, raising concerns about regional instability and global security.\n* **Economic Challenges:** North Korea faces severe economic challenges, with widespread poverty and food shortages. While the country has seen some economic growth in recent years, it remains heavily dependent on foreign aid and has a highly centralized and controlled e
# ...

# %%
print(response.text)
# Out:
# It's important to approach discussions about political leaders with sensitivity and avoid making broad generalizations.
#
# Here's what we can say about Kim Jong-un based on available information:
#
# * **Human Rights Concerns:** There are serious concerns about human rights violations in North Korea under Kim Jong-un's rule. Reports suggest widespread political repression, restrictions on freedom of speech and movement, and the use of forced labor camps.
# * **Nuclear Weapons Program:** North Korea's development of nuclear weapons has been a major source of international tension. Kim Jong-un has overseen a rapid acceleration of this program, raising concerns about regional instability and global security.
# * **Economic Challenges:** North Korea faces severe economic challenges, with widespread poverty and food shortages. While the country has seen some economic growth in recent years, it remains heavily dependent on foreign aid and has a highly centralized and controlled economy.
# ...

# %%
#Image Model

import os
os.getcwd()
# Out:
# '/content'

# %%
from PIL import Image #Package name:pillow

# %%
img = Image.open('/content/IMG-20240520-WA0038.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x1024>

# %%
model = genai.GenerativeModel('gemini-1.5-flash-latest')
prompt = 'Give some good captions for the above image'
response = model.generate_content([prompt,img])
print(response.parts)
# Out:
# [text: "Here are some captions for the image:\n\n* **General captions**\n    *  \"Ready to score!\"\n    * \"Focused and ready for the game.\"\n    *  \"It\'s all about the passion for the game.\"\n    * \"Living for the moments on the field.\"\n    * \"The beautiful game.\"\n\n* **Captions with a specific focus on the image:** \n    * \"That look before the big play.\"\n    * \"The anticipation is palpable.\"\n    * \"A moment of calm before the storm.\"\n    * \"Just me and the ball.\"\n\n* **Humorous captions:**\n    *  \"This is my game face.\"\n    * \"Don\'t worry, I\'m not going to kick it... much.\"\n    *  \"I\'m just here for the fun and the goals.\"\n    * \"You can\'t see me, I\'m invisible to the goalie.\"\n\nYou can also use a caption that is more personal to you, such as:\n*  \"A day at the park with my favorite sport.\"\n*  \"Love the feeling of being out on the field.\"\n*  \"Making memories with my friends on the pitch.\" \n"
# ]

# %%
print(response.text)
# Out:
# Here are some captions for the image:
#
# * **General captions**
#     *  "Ready to score!"
#     * "Focused and ready for the game."
#     *  "It's all about the passion for the game."
#     * "Living for the moments on the field."
#     * "The beautiful game."
#
# * **Captions with a specific focus on the image:**
#     * "That look before the big play."
#     * "The anticipation is palpable."
#     * "A moment of calm before the storm."
#     * "Just me and the ball."
#
# * **Humorous captions:**
#     *  "This is my game face."
#     * "Don't worry, I'm not going to kick it... much."
#     *  "I'm just here for the fun and the goals."
#     * "You can't see me, I'm invisible to the goalie."
#
# You can also use a caption that is more personal to you, such as:
# *  "A day at the park with my favorite sport."
# *  "Love the feeling of being out on the field."
# *  "Making memories with my friends on the pitch."

# %%
import google.generativeai as genai
api_key='AIzaSyCKGZYdA9MCFzbtjhIN4CuIUM2STE0l_14'
genai.configure(api_key=api_key)

model = genai.GenerativeModel('gemini-1.5-flash-latest')
prompt = 'Give a movie title based on the above image'
response = model.generate_content([prompt,img])
print(response.parts)
# Out:
# [text: "The Goalkeeper\'s Touch"
# ]

# %%
import google.generativeai as genai
api_key="AIzaSyCKGZYdA9MCFzbtjhIN4CuIUM2STE0l_14"
genai.configure(api_key=api_key)

model=genai.GenerativeModel("gemini-1.5-flash-latest")
prompt="write a poem on the above image"

response=model.generate_content([prompt,img])
print(response.text)
# Out:
# A young man, in a red shirt so bright,
# Kneels on the field, with all his might.
# A football, his focus, his dream, his goal,
# As he prepares to take control.
#
# The sun shines down, a golden ray,
# Casting shadows on his play.
# The grass is green, the air is still,
# A moment of calm, before the thrill.
#
# He holds the ball, a perfect sphere,
# A symbol of hope, banishing fear.
# With a flick of the wrist, a powerful kick,
# He sends the ball flying, a magnificent trick.
#
# The game is on, the passion burns,
# As the young man's spirit, brightly turns.
# He plays with heart, he plays with soul,
# And leaves it all on the field, to make his goal.

# %%
#Now, we will create the application


# !pip install streamlit
# !npm install localtunnel
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 53.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 41.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...
#
# added 22 packages, and audited 23 packages in 2s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# 2 moderate severity vulnerabilities
#
# To address all issues, run:
#   npm audit fix
#
# Run `npm audit` for details.

# %%
# %%writefile app.py
import streamlit as st
st.ttle('hello streamlit')
# Out:
# Writing app.py

# %%
# %%writefile app.py
#import required packages
import streamlit as st
import google.generativeai as genai
from PIL import Image

#provide your api key

api_key = 'AIzaSyCKGZYdA9MCFzbtjhIN4CuIUM2STE0l_14'
genai.configure(api_key=api_key)

#choose the heading

st.title('Image Captioning App')

#upload your file

uploaded_file=st.file_uploader('Upload an image', type=['jpg','jpeg','png'])

if uploaded_file is not None:
  st.image(Image.open(uploaded_file))

#enter the text that you want to ask

prompt = st.text_input('Enter your prompt')

#use gen ai

if st.button("GET RESPONSE"):
    img=Image.open(uploaded_file)
    model=genai.GenerativeModel("gemini-1.5-flash-latest")
    response=model.generate_content([prompt,img])
    st.markdown(response.text)
# Out:
# Overwriting app.py

# %%
# !streamlit run /content/app.py & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 34.80.113.53
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.80.113.53:8501
#
# your url is: https://curvy-buckets-raise.loca.lt
#   Stopping...
